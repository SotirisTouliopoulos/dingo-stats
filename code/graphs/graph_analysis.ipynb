# %%
import sys
sys.path.insert(0, '/home/touliopoulos/project/erasmus/erasmus_2025_project/code/load_modify_sample')
from load_modify_sample_utils import load_model, get_objective_functions, get_reaction_bounds, modify_model, sample_gapsplit, plot_grid_95_reactions
from load_modify_sample_utils import sample_dingo, sample_optgp, sampling_statistics


sys.path.insert(0, '/home/touliopoulos/project/erasmus/erasmus_2025_project/code/correlations')
from correlations_utils import linear_correlations_in_reactions, plot_correlation_matrix


from graphs_utils import construct_graph, plot_graph
# Out:
# /home/touliopoulos/.local/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /home/touliopoulos/.local/lib/python3.10/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.2' currently installed).
#   from pandas.core import (

# %%
ec_cobra_model, ec_cobra_reactions, ec_dingo_model, ec_dingo_reactions = load_model("/home/touliopoulos/project/erasmus/erasmus_2025_project/ext_data/models/e_coli_core.xml")

objective_functions = get_objective_functions(ec_cobra_model)
print(objective_functions)

default_reaction_bounds = get_reaction_bounds(ec_cobra_model)
print(default_reaction_bounds)
# Out:
# Set parameter Username
# Set parameter LicenseID to value 2642044
# Academic license - for non-commercial use only - expires 2026-03-25
# ['BIOMASS_Ecoli_core_w_GAM']
# {'PFK': (0.0, 1000.0), 'PFL': (0.0, 1000.0), 'PGI': (-1000.0, 1000.0), 'PGK': (-1000.0, 1000.0), 'PGL': (0.0, 1000.0), 'ACALD': (-1000.0, 1000.0), 'AKGt2r': (-1000.0, 1000.0), 'PGM': (-1000.0, 1000.0), 'PIt2r': (-1000.0, 1000.0), 'ALCD2x': (-1000.0, 1000.0), 'ACALDt': (-1000.0, 1000.0), 'ACKr': (-1000.0, 1000.0), 'PPC': (0.0, 1000.0), 'ACONTa': (-1000.0, 1000.0), 'ACONTb': (-1000.0, 1000.0), 'ATPM': (8.39, 1000.0), 'PPCK': (0.0, 1000.0), 'ACt2r': (-1000.0, 1000.0), 'PPS': (0.0, 1000.0), 'ADK1': (-1000.0, 1000.0), 'AKGDH': (0.0, 1000.0), 'ATPS4r': (-1000.0, 1000.0), 'PTAr': (-1000.0, 1000.0), 'PYK': (0.0, 1000.0), 'BIOMASS_Ecoli_core_w_GAM': (0.0, 1000.0), 'PYRt2': (-1000.0, 1000.0), 'CO2t': (-1000.0, 1000.0), 'RPE': (-1000.0, 1000.0), 'CS': (0.0, 1000.0), 'RPI': (-1000.0, 1000.0), 'SUCCt2_2': (0.0, 1000.0), 'CYTBD': (0.0, 1000.0), 'D_LACt2': (-1000.0, 1000.0), 'ENO': (-1000.0, 1000.0), 'SUCCt3': (0.0, 1000.0), 'ETOHt2r': (-1000.0, 1000.0), 'SUCDi': (0.0, 1000.0), 'SUCOAS': (-1000.0, 1000.0), 'TALA': (-1000.0, 1000.0), 'THD2': (0.0, 1000.0), 'TKT1': (-1000.0, 1000.0), 'TKT2': (-1000.0, 1000.0), 'TPI': (-1000.0, 1000.0), 'EX_ac_e': (0.0, 1000.0), 'EX_acald_e': (0.0, 1000.0), 'EX_akg_e': (0.0, 1000.0), 'EX_co2_e': (-1000.0, 1000.0), 'EX_etoh_e': (0.0, 1000.0), 'EX_for_e': (0.0, 1000.0), 'EX_fru_e': (0.0, 1000.0), 'EX_fum_e': (0.0, 1000.0), 'EX_glc__D_e': (-10.0, 1000.0), 'EX_gln__L_e': (0.0, 1000.0), 'EX_glu__L_e': (0.0, 1000.0), 'EX_h_e': (-1000.0, 1000.0), 'EX_h2o_e': (-1000.0, 1000.0), 'EX_lac__D_e': (0.0, 1000.0), 'EX_mal__L_e': (0.0, 1000.0), 'EX_nh4_e': (-1000.0, 1000.0), 'EX_o2_e': (-1000.0, 1000.0), 'EX_pi_e': (-1000.0, 1000.0), 'EX_pyr_e': (0.0, 1000.0), 'EX_succ_e': (0.0, 1000.0), 'FBA': (-1000.0, 1000.0), 'FBP': (0.0, 1000.0), 'FORt2': (0.0, 1000.0), 'FORt': (-1000.0, 0.0), 'FRD7': (0.0, 1000.0), 'FRUpts2': (0.0, 1000.0), 'FUM': (-1000.0, 1000.0), 'FUMt2_2': (0.0, 1000.0), 'G6PDH2r': (-1000.0, 1000.0), 'GAPD': (-1000.0, 1000.0), 'GLCpts': (0.0, 1000.0), 'GLNS': (0.0, 1000.0), 'GLNabc': (0.0, 1000.0), 'GLUDy': (-1000.0, 1000.0), 'GLUN': (0.0, 1000.0), 'GLUSy': (0.0, 1000.0), 'GLUt2r': (-1000.0, 1000.0), 'GND': (0.0, 1000.0), 'H2Ot': (-1000.0, 1000.0), 'ICDHyr': (-1000.0, 1000.0), 'ICL': (0.0, 1000.0), 'LDH_D': (-1000.0, 1000.0), 'MALS': (0.0, 1000.0), 'MALt2_2': (0.0, 1000.0), 'MDH': (-1000.0, 1000.0), 'ME1': (0.0, 1000.0), 'ME2': (0.0, 1000.0), 'NADH16': (0.0, 1000.0), 'NADTRHD': (0.0, 1000.0), 'NH4t': (-1000.0, 1000.0), 'O2t': (-1000.0, 1000.0), 'PDH': (0.0, 1000.0)}

# %%
ec_cobra_model_condition_1, ec_dingo_model_condition_1 = modify_model(ec_cobra_model, objective_function="BIOMASS_Ecoli_core_w_GAM", optimal_percentage=50)
ec_cobra_model_condition_2, ec_dingo_model_condition_2 = modify_model(ec_cobra_model, objective_function="BIOMASS_Ecoli_core_w_GAM", optimal_percentage=50)


samples_optgp_condition_1 = sample_optgp(ec_cobra_model_condition_1, n_samples = 3000, thinning=1, reaction_in_rows = True)
samples_optgp_condition_2 = sample_optgp(ec_cobra_model_condition_2, n_samples = 3000, thinning=100, reaction_in_rows = True)
# Out:
# Read LP format model from file /tmp/tmpy98adeoq.lp
# Reading time = 0.01 seconds
# : 72 rows, 190 columns, 720 nonzeros
# Read LP format model from file /tmp/tmpyzz_3e21.lp
# Reading time = 0.00 seconds
# : 72 rows, 190 columns, 720 nonzeros
# Read LP format model from file /tmp/tmp13wi12e2.lp
# Reading time = 0.00 seconds
# : 72 rows, 190 columns, 720 nonzeros
# Read LP format model from file /tmp/tmpen7p__46.lp
# Reading time = 0.00 seconds
# : 72 rows, 190 columns, 720 nonzeros

# %%
correlation_matrix_condition_1, filtered_correlation_matrix_condition_1 = linear_correlations_in_reactions(samples_optgp_condition_1, ec_cobra_model, pearson_cutoff = 0)
print(correlation_matrix_condition_1.shape)

correlation_matrix_condition_2, filtered_correlation_matrix_condition_2 = linear_correlations_in_reactions(samples_optgp_condition_2, ec_cobra_model, pearson_cutoff = 0)
print(correlation_matrix_condition_2.shape)
# Out:
# (95, 95)
# (95, 95)
# /home/touliopoulos/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2853: RuntimeWarning:
#
# invalid value encountered in divide
#
# /home/touliopoulos/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning:
#
# invalid value encountered in divide

# %%
G_condition_1, layout_condition_1  = construct_graph(correlation_matrix_condition_1,
                cobra_model = ec_cobra_model,
                correction=True,
                remove_unconnected_nodes = True
                )
plot_graph(G_condition_1, layout_condition_1)


G_condition_2, layout_condition_2 = construct_graph(correlation_matrix_condition_2,
                cobra_model = ec_cobra_model,
                correction=True,
                remove_unconnected_nodes = True
                )
plot_graph(G_condition_2, layout_condition_2)

# %%
import numpy as np
import networkx as nx

# Degree centrality - requires full nodes
#degrees1 = np.array([G_condition_1.degree(n) for n in G_condition_1.nodes()])
#degrees2 = np.array([G_condition_2.degree(n) for n in G_condition_2.nodes()])
#for index, value in enumerate(degrees1 - degrees2):
#    if abs(value) >= 0:
#        print(list(G_condition_1.nodes())[index], list(G_condition_1.nodes())[index], value)
#        #pass


# same as above but with weights and absolute edges
degrees1 = np.array([G_condition_1.degree(n, weight='weight') for n in G_condition_1.nodes()])
degrees2 = np.array([G_condition_2.degree(n, weight='weight') for n in G_condition_2.nodes()])
for index, value in enumerate(degrees1 - degrees2):
    if abs(value) >= 1:
        print(list(G_condition_1.nodes())[index], value)
        #pass


print("\n")


#closeness_G1 = nx.closeness_centrality(G_condition_1, distance="1/weight")
#closeness_G2 = nx.closeness_centrality(G_condition_2, distance="1/weight")
#closeness_diff = {node: closeness_G2.get(node, 0) - closeness_G1.get(node, 0) for node in set(G_condition_1.nodes()).union(G_condition_2.nodes())}
#sorted_nodes = sorted(closeness_diff.items(), key=lambda x: x[1], reverse=True)

#for node, change in sorted_nodes:
#        print(f"Node {node}: ΔCloseness = {change:.4f}")


print("\n")


centrality_G1 = nx.betweenness_centrality(G_condition_1, weight='weight', normalized=True)
centrality_G2 = nx.betweenness_centrality(G_condition_2, weight='weight', normalized=True)
centrality_diff = {node: centrality_G2.get(node, 0) - centrality_G1.get(node, 0) for node in set(G_condition_1.nodes()).union(G_condition_2.nodes())}
sorted_nodes = sorted(centrality_diff.items(), key=lambda x: x[1], reverse=True)

for node, change in sorted_nodes:
        print(f"Node {node}: ΔCentrality = {change:.4f}")
# Out:
# PFL 13.835861635046559
# PGI 7.764154572362539
# PGK 7.011804040978856
# PGL 7.680912451806776
# ACALD 5.663240855774481
# AKGt2r 3.848226977034516
# PGM 6.981668821229103
# PIt2r 4.191489015025305
# ALCD2x 9.985876655896897
# ACKr 2.3679454266522573
# PPC 9.175981856120401
# ACONTa 1.1423108648194358
# ACONTb 1.1423108648194358
# ATPM 5.8638128610362426
# PPCK 10.920618468207874
# ACt2r 2.3679454266522573
# PPS 3.413327390779573
# ADK1 3.413327390779573
# AKGDH 9.57694864660908
# ATPS4r 10.09791231204753
# PTAr 2.3679454266522573
# PYK 4.035274457409722
# BIOMASS_Ecoli_core_w_GAM 4.191489015025295
# PYRt2 15.03913762626284
# CO2t 8.753142702252006
# RPE 7.660722492874882
# CS 1.1423108648194358
# RPI 7.721777230344145
# SUCCt2_2 7.61399846176157
# CYTBD 7.777596730621088
# D_LACt2 4.824554122426619
# ENO 6.981668821229132
# SUCCt3 7.247106222039655
# ETOHt2r 9.985876655896897
# SUCDi 16.19003367407819
# SUCOAS 9.57694864660908
# TALA 7.670842072076958
# THD2 6.7070936560666174
# TKT1 7.670842072076962
# TKT2 7.650644120659596
# TPI 7.5103195046166995
# EX_ac_e 2.367945426652259
# EX_akg_e 3.8482269770345177
# EX_co2_e 8.75314270225201
# EX_etoh_e 9.985876655896897
# EX_for_e 13.835861635046548
# EX_glc__D_e 6.055927913886907
# EX_glu__L_e 5.216036293438913
# EX_h_e 12.372443739438772
# EX_h2o_e 9.938656235904862
# EX_lac__D_e 4.824554122426618
# EX_nh4_e 5.161016041657865
# EX_o2_e 7.777596730621088
# EX_pi_e 4.191489015025305
# EX_pyr_e 15.039137626262843
# EX_succ_e 4.724778764633881
# FBA 7.5103195046166995
# FBP 11.191251340807822
# FORt2 4.669476118024131
# FORt 4.909564560628971
# FRD7 16.236653907492155
# G6PDH2r 7.68091245180678
# GAPD 7.011804040978866
# GLCpts 6.055927913886907
# GLNS 9.10929029954944
# GLUDy 9.350469136528083
# GLUN 11.519249026381388
# GLUSy 9.668878390598968
# GLUt2r 5.216036293438915
# GND 7.680912451806783
# H2Ot 9.938656235904855
# ICDHyr 9.737198013166118
# ICL 3.7058999295607364
# LDH_D 4.824554122426618
# MALS 3.705899929560738
# ME1 5.625314440367626
# ME2 7.106256595915948
# NADH16 7.699253856771385
# NADTRHD 1.958421269809481
# NH4t 5.161016041657863
# O2t 7.777596730621088
# PDH 4.4168151912478955
#
#
#
#
# Node FRD7: ΔCentrality = 0.5267
# Node ATPM: ΔCentrality = 0.1453
# Node PGI: ΔCentrality = 0.0867
# Node MDH: ΔCentrality = 0.0810
# Node SUCDi: ΔCentrality = 0.0791
# Node RPI: ΔCentrality = 0.0736
# Node GAPD: ΔCentrality = 0.0492
# Node TKT2: ΔCentrality = 0.0287
# Node FORt: ΔCentrality = 0.0252
# Node NH4t: ΔCentrality = 0.0187
# Node GLUt2r: ΔCentrality = 0.0167
# Node PPCK: ΔCentrality = 0.0161
# Node EX_pyr_e: ΔCentrality = 0.0093
# Node PYRt2: ΔCentrality = 0.0093
# Node ATPS4r: ΔCentrality = 0.0090
# Node BIOMASS_Ecoli_core_w_GAM: ΔCentrality = 0.0088
# Node GLUN: ΔCentrality = 0.0071
# Node ENO: ΔCentrality = 0.0068
# Node PDH: ΔCentrality = 0.0057
# Node PFK: ΔCentrality = 0.0044
# Node PGK: ΔCentrality = 0.0036
# Node PIt2r: ΔCentrality = 0.0028
# Node MALS: ΔCentrality = 0.0025
# Node AKGDH: ΔCentrality = 0.0019
# Node EX_etoh_e: ΔCentrality = 0.0018
# Node SUCOAS: ΔCentrality = 0.0016
# Node D_LACt2: ΔCentrality = 0.0016
# Node LDH_D: ΔCentrality = 0.0016
# Node EX_lac__D_e: ΔCentrality = 0.0016
# Node ACONTb: ΔCentrality = 0.0012
# Node CS: ΔCentrality = 0.0012
# Node ACONTa: ΔCentrality = 0.0012
# Node ALCD2x: ΔCentrality = 0.0011
# Node ETOHt2r: ΔCentrality = 0.0011
# Node EX_for_e: ΔCentrality = 0.0008
# Node ACALD: ΔCentrality = 0.0000
# Node G6PDH2r: ΔCentrality = 0.0000
# Node EX_o2_e: ΔCentrality = 0.0000
# Node PGL: ΔCentrality = 0.0000
# Node CO2t: ΔCentrality = 0.0000
# Node TKT1: ΔCentrality = 0.0000
# Node CYTBD: ΔCentrality = 0.0000
# Node EX_co2_e: ΔCentrality = 0.0000
# Node O2t: ΔCentrality = 0.0000
# Node TALA: ΔCentrality = 0.0000
# Node FUM: ΔCentrality = 0.0000
# Node NADH16: ΔCentrality = 0.0000
# Node GND: ΔCentrality = 0.0000
# Node RPE: ΔCentrality = 0.0000
# Node FBA: ΔCentrality = 0.0000
# Node TPI: ΔCentrality = 0.0000
# Node H2Ot: ΔCentrality = -0.0008
# Node EX_h2o_e: ΔCentrality = -0.0008
# Node ACKr: ΔCentrality = -0.0029
# Node PTAr: ΔCentrality = -0.0029
# Node ACt2r: ΔCentrality = -0.0029
# Node EX_ac_e: ΔCentrality = -0.0029
# Node EX_glu__L_e: ΔCentrality = -0.0044
# Node PGM: ΔCentrality = -0.0068
# Node PFL: ΔCentrality = -0.0096
# Node ICL: ΔCentrality = -0.0101
# Node SUCCt2_2: ΔCentrality = -0.0115
# Node EX_h_e: ΔCentrality = -0.0118
# Node ICDHyr: ΔCentrality = -0.0153
# Node EX_pi_e: ΔCentrality = -0.0176
# Node FORt2: ΔCentrality = -0.0202
# Node EX_akg_e: ΔCentrality = -0.0216
# Node FBP: ΔCentrality = -0.0244
# Node AKGt2r: ΔCentrality = -0.0257
# Node ME2: ΔCentrality = -0.0293
# Node GLUSy: ΔCentrality = -0.0347
# Node GLCpts: ΔCentrality = -0.0406
# Node EX_glc__D_e: ΔCentrality = -0.0406
# Node PYK: ΔCentrality = -0.0449
# Node GLNS: ΔCentrality = -0.0454
# Node NADTRHD: ΔCentrality = -0.0553
# Node EX_nh4_e: ΔCentrality = -0.0642
# Node PPS: ΔCentrality = -0.0674
# Node ADK1: ΔCentrality = -0.0674
# Node EX_succ_e: ΔCentrality = -0.0689
# Node ACALDt: ΔCentrality = -0.0746
# Node PPC: ΔCentrality = -0.0834
# Node EX_acald_e: ΔCentrality = -0.0835
# Node THD2: ΔCentrality = -0.0960
# Node SUCCt3: ΔCentrality = -0.1094
# Node GLUDy: ΔCentrality = -0.1182
# Node ME1: ΔCentrality = -0.1483
